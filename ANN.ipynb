# %% [markdown]
# Import Libaraies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, classification_report, recall_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import roc_curve, auc
#from imblearn.over_sampling import RandomOverSampler
# Out:
# WARNING:tensorflow:From C:\Users\iraha\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Load The dataset

# %%
data = pd.read_csv('Datasets\FinalCreditCard.csv')
data
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 0          0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 4996  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 4997  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 4998  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 4999  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 0     0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1    -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2     0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3     0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4     0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...        ...       ...       ...  ...       ...       ...       ...
# 4995 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 4996 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 4997 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 4998 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 4999  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#            V24       V25       V26       V27       V28  Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1    -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3    -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4     0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0
# ...        ...       ...       ...       ...       ...     ...    ...
# 4995 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 4996 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 4997  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 4998 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 4999 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [5000 rows x 31 columns]

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# Since our dataset is already scaled, except for the amount and time columns, they are left to scale. So, the procedure we will apply in the preprocessing data phase is as follows:
# * using RobustScaler to scale time and amount columns because it is not affected by a small number of huge marginal outliers.

# %%
# taking the fraud and not fruad data separtely 
fraud = data[data['Class'] == 1]
notfraud = data[data['Class'] == 0]

# %%
rob_scaler = RobustScaler()
#Scale Time and Amount coloumns
data['scaled_amount'] = rob_scaler.fit_transform(data['Amount'].values.reshape(-1,1))
data['scaled_time'] = rob_scaler.fit_transform(data['Time'].values.reshape(-1,1))

# %%
#Remove the coloumns before, becase we already done scaling
data.drop(['Time','Amount'], axis=1, inplace=True)

scaled_amount = data['scaled_amount']
scaled_time = data['scaled_time']

# %%
data.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)

# Put the new columns in suitable order
data.insert(0, 'scaled_amount', scaled_amount)
data.insert(1, 'scaled_time', scaled_time)

# %%
#the data after is completely scaled 
fraud = data[data['Class'] == 1]
notfraud = data[data['Class'] == 0]
data.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       2.303559    -0.909889 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.210643    -0.909889  1.191857  0.266151  0.166480  0.448154
# 2       6.222793    -0.909450 -1.358354 -1.340163  1.773209  0.379780
# 3       1.856605    -0.909450 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.940965    -0.909011 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# 0 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053      0
# 1  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724      0
# 2  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0
# 3 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458      0
# 4 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153      0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Training Phase
# As our dataset is clearly unbalanced, we will utilize the StratifiedShuffleSplit() function. This function is used to split the data into train and test sets by their indices. StratifiedShuffleSplit() is a Cross-Validation object that combines two things, which are ShuffleSplit and StratifiedKFold, and it produces Stratified Randomize Folds. Those folds are made by maintaining the percentage of samples for each class.

# %%
# to see the percentages of fraud and non fraud (class Distribution)
print('Not Frauds', round(data['Class'].value_counts()[0]/len(data) * 100,2), '% of the dataset')
print('Frauds', round(data['Class'].value_counts()[1]/len(data) * 100,2), '% of the dataset')
# Out:
# Not Frauds 90.16 % of the dataset
# Frauds 9.84 % of the dataset

# %%
X = data.drop('Class', axis=1)
y = data['Class']
X
# Out:
#       scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0          2.303559    -0.909889 -1.359807 -0.072781  2.536347  1.378155
# 1         -0.210643    -0.909889  1.191857  0.266151  0.166480  0.448154
# 2          6.222793    -0.909450 -1.358354 -1.340163  1.773209  0.379780
# 3          1.856605    -0.909450 -0.966272 -0.185226  1.792993 -0.863291
# 4          0.940965    -0.909011 -1.158233  0.877737  1.548718  0.403034
# ...             ...          ...       ...       ...       ...       ...
# 4995       6.416838    73.348480 -1.927883  1.125653 -4.518331  1.749293
# 4996      -0.243669    73.438481  1.378559  1.289381 -5.004247  1.411850
# 4997       1.076146    73.440237 -0.676143  1.126366 -2.213700  0.468308
# 4998       3.935661    73.710240 -3.113832  0.585864 -5.399730  1.817092
# 4999       0.471081    73.877950  1.991976  0.158476 -2.583441  0.408670
#
#             V5        V6        V7        V8  ...       V19       V20  \
# 0    -0.338321  0.462388  0.239599  0.098698  ...  0.403993  0.251412
# 1     0.060018 -0.082361 -0.078803  0.085102  ... -0.145783 -0.069083
# 2    -0.503198  1.800499  0.791461  0.247676  ... -2.261857  0.524980
# 3    -0.010309  1.247203  0.237609  0.377436  ... -1.232622 -0.208038
# 4    -0.407193  0.095921  0.592941 -0.270533  ...  0.803487  0.408542
# ...        ...       ...       ...       ...  ...       ...       ...
# 4995 -1.566487 -2.010494 -0.882850  0.697211  ...  0.391167  1.252967
# 4996  0.442581 -1.326536 -1.413170  0.248525  ...  0.737657  0.226138
# 4997 -1.120541 -0.003346 -2.234739  1.210158  ...  0.266272  0.247968
# 4998 -0.840618 -2.943548 -2.208002  1.058733  ... -0.035480  0.306271
# 4999  1.151147 -0.096695  0.223050 -0.068384  ...  0.593509 -0.017652
#
#            V21       V22       V23       V24       V25       V26       V27  \
# 0    -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1    -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2     0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3    -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4    -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  0.778584 -0.319189  0.639419 -0.294885  0.537503  0.788395  0.292680
# 4996  0.370612  0.028234 -0.145640 -0.081049  0.521875  0.739467  0.389152
# 4997  0.751826  0.834108  0.190944  0.032070 -0.739695  0.471111  0.385107
# 4998  0.583276 -0.269209 -0.456108 -0.183659 -0.328168  0.606116  0.884876
# 4999 -0.164350 -0.295135 -0.072173 -0.450261  0.313267 -0.289617  0.002988
#
#            V28
# 0    -0.021053
# 1     0.014724
# 2    -0.059752
# 3     0.061458
# 4     0.215153
# ...        ...
# 4995  0.147968
# 4996  0.186637
# 4997  0.194361
# 4998 -0.253700
# 4999 -0.015309
#
# [5000 rows x 30 columns]

# %%
#to extract 70% of the datasets and Stratified Shuffle Split for balance distribution while training
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)

# %%
for train_index, test_index in sss.split(X, y):
    print("Train:", train_index, "Test:", test_index)
    data_Xtrain, data_Xtest = X.iloc[train_index], X.iloc[test_index]
    data_ytrain, data_ytest = y.iloc[train_index], y.iloc[test_index]
# Out:
# Train: [4327 4175  282 ... 1837 1914 3282] Test: [1930 2723 1968 ... 2956 3674 3090]

# %%
#to check the distribution of data
train_unique_label, train_counts_label = np.unique(data_ytrain, return_counts=True)
test_unique_label, test_counts_label = np.unique(data_ytest, return_counts=True)
print('-' * 50)

print('Label Distributions: [Fraud Not-Fraud]')
print('Train: {}'.format(train_counts_label/ len(data_ytrain)))
print(train_counts_label)
print('Test: {}'.format(test_counts_label/ len(data_ytest)))
print(test_counts_label)
# Out:
# --------------------------------------------------
# Label Distributions: [Fraud Not-Fraud]
# Train: [0.90171429 0.09828571]
# [3156  344]
# Test: [0.90133333 0.09866667]
# [1352  148]

# %%
import itertools

#to prints and plots the confusion matrix 
#for normilization, it is done by setting normalize=True

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix',cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# # Building the model phase
# We built a sequential model that used three layers. The first one is the input layer, which uses 32 norouns and ReLU as an activation function. Also, we set the input dimensionality to 29, as we have 29 features in our dataset. Secondly, we only set up one hidden layer that has 16 neurons and ReLU functions. Lastly, the output layer only has 1 neuron because of the binary classification of the class column and Sigmaiod as the output activation function.
# However, we used the Adam optimizer, binary_crossentropy is a loss function, and accuracy is a performance matrix to measure the accuracy of each fold of cross validation.

# %%
# we used StratifiedShuffleSplit for cross-validation and split it to 7 folds
sss = StratifiedShuffleSplit(n_splits=7, test_size=0.0015, random_state=42)

# we initialize the model
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=30))  
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# we compile the model with adam optimizer and binar
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# we initialize scaler
scaler = RobustScaler()
history_list = []

# we initialize an array to store accuracy scores for each fold
accuracy_scores = []
# Out:
# WARNING:tensorflow:From C:\Users\iraha\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\iraha\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
for train_val_index, test_val_index in sss.split(data_Xtrain, data_ytrain):
    X_train, X_val = data_Xtrain.iloc[train_val_index], data_Xtrain.iloc[test_val_index]
    y_train, y_val = data_ytrain.iloc[train_val_index], data_ytrain.iloc[test_val_index]

    train_val_data = X_train
    train_val_data = train_val_data.assign(Class=y_train)

    fraud_df = train_val_data.loc[train_val_data['Class'] == 1]
    notfraud_df = train_val_data.loc[train_val_data['Class'] == 0].sample(len(fraud_df))
    print('Relation fraud and non-fraud in the CV set:{} x {}'.format(len(fraud_df), len(notfraud_df)))

    print('Test training relationship {} X {}'.format(len(notfraud_df)+len(fraud_df), len(y_val)))
    print('Test training relationship {} X {}'.format((len(notfraud_df)+len(fraud_df))/(len(notfraud_df)+len(fraud_df)+len(y_val)), len(y_val)/(len(notfraud_df)+len(fraud_df)+len(y_val))))
    
    X_train_resampled = pd.concat([fraud_df, notfraud_df]).drop('Class', axis=1)
    y_train_resampled = pd.concat([fraud_df, notfraud_df])['Class']
    

    # to scale the data
    X_train_scaled = scaler.fit_transform(X_train_resampled)
    X_val_scaled = scaler.transform(X_val)
    
    # to fit the model
    early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    history = model.fit(x=X_train_scaled, y=y_train_resampled, epochs=10, validation_data=(X_val_scaled, y_val),
                        callbacks=[early_stop])

    history_list.append(history.history)
    
    # to evaluate the model
    loss, accuracy = model.evaluate(X_val_scaled, y_val)
    print("Validation Accuracy: {}".format(accuracy))
    accuracy_scores.append(accuracy)
# Out:
# Relation fraud and non-fraud in the CV set:343 x 343
# Test training relationship 686 X 6
# Test training relationship 0.9913294797687862 X 0.008670520231213872
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\iraha\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\iraha\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 22/22 [==============================] - 2s 27ms/step - loss: 0.7463 - accuracy: 0.5729 - val_loss: 0.5263 - val_accuracy: 0.8333
# Epoch 2/10
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4849 - accuracy: 0.8309 - val_loss: 0.4118 - val_accuracy: 1.0000
# Epoch 3/10
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3939 - accuracy: 0.8907 - val_loss: 0.3070 - val_accuracy: 1.0000
# Epoch 4/10
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3257 - accuracy: 0.9125 - val_loss: 0.2359 - val_accuracy: 1.0000
# Epoch 5/10
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2700 - accuracy: 0.9344 - val_loss: 0.1717 - val_accuracy: 1.0000
# Epoch 6/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2255 - accuracy: 0.9417 - val_loss: 0.1300 - val_accuracy: 1.0000
# Epoch 7/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1866 - accuracy: 0.9519 - val_loss: 0.0997 - val_accuracy: 1.0000
# Epoch 8/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1557 - accuracy: 0.9606 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 9/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1293 - accuracy: 0.9665 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 10/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1098 - accuracy: 0.9723 - val_loss: 0.0499 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0499 - accuracy: 1.0000
# Validation Accuracy: 1.0
# Relation fraud and non-fraud in the CV set:343 x 343
# Test training relationship 686 X 6
# Test training relationship 0.9913294797687862 X 0.008670520231213872
# Epoch 1/10
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0951 - accuracy: 0.9738 - val_loss: 0.1535 - val_accuracy: 1.0000
# Epoch 2/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0804 - accuracy: 0.9781 - val_loss: 0.1413 - val_accuracy: 1.0000
# Epoch 3/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 0.9796 - val_loss: 0.1174 - val_accuracy: 1.0000
# Epoch 4/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0606 - accuracy: 0.9840 - val_loss: 0.1054 - val_accuracy: 1.0000
# Epoch 5/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0536 - accuracy: 0.9840 - val_loss: 0.0944 - val_accuracy: 1.0000
# Epoch 6/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9854 - val_loss: 0.0863 - val_accuracy: 1.0000
# Epoch 7/10
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0424 - accuracy: 0.9883 - val_loss: 0.0745 - val_accuracy: 1.0000
# Epoch 8/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.9913 - val_loss: 0.0614 - val_accuracy: 1.0000
# Epoch 9/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0350 - accuracy: 0.9927 - val_loss: 0.0578 - val_accuracy: 1.0000
# Epoch 10/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0324 - accuracy: 0.9927 - val_loss: 0.0481 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0481 - accuracy: 1.0000
# Validation Accuracy: 1.0
# Relation fraud and non-fraud in the CV set:343 x 343
# Test training relationship 686 X 6
# Test training relationship 0.9913294797687862 X 0.008670520231213872
# Epoch 1/10
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0418 - accuracy: 0.9869 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 2/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0353 - accuracy: 0.9854 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 3/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 0.9898 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 4/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0281 - accuracy: 0.9913 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 5/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0257 - accuracy: 0.9942 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 6/10
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0236 - accuracy: 0.9956 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 7/10
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0218 - accuracy: 0.9956 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 8/10
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0201 - accuracy: 0.9956 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 9/10
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0187 - accuracy: 0.9971 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 10/10
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9971 - val_loss: 0.0073 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0073 - accuracy: 1.0000
# Validation Accuracy: 1.0
# Relation fraud and non-fraud in the CV set:343 x 343
# Test training relationship 686 X 6
# Test training relationship 0.9913294797687862 X 0.008670520231213872
# Epoch 1/10
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0175 - accuracy: 0.9956 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 2/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 3/10
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 4/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9971 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 5/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9985 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 6/10
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0116 - accuracy: 0.9985 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 7/10
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0107 - accuracy: 0.9985 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 8/10
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0100 - accuracy: 0.9985 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 9/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0093 - accuracy: 0.9985 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 10/10
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.0027 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0027 - accuracy: 1.0000
# Validation Accuracy: 1.0
# Relation fraud and non-fraud in the CV set:343 x 343
# Test training relationship 686 X 6
# Test training relationship 0.9913294797687862 X 0.008670520231213872
# Epoch 1/10
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0123 - accuracy: 0.9971 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 2/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9971 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 3/10
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 4/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 5/10
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 6/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 7/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 8/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 9/10
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 10/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0014 - accuracy: 1.0000
# Validation Accuracy: 1.0
# Relation fraud and non-fraud in the CV set:343 x 343
# Test training relationship 686 X 6
# Test training relationship 0.9913294797687862 X 0.008670520231213872
# Epoch 1/10
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 2/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 3/10
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 4/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 5/10
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 6/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 7/10
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 8/10
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 9.9181e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 9.2144e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 8.5696e-04 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 38ms/step - loss: 8.5696e-04 - accuracy: 1.0000
# Validation Accuracy: 1.0
# Relation fraud and non-fraud in the CV set:343 x 343
# Test training relationship 686 X 6
# Test training relationship 0.9913294797687862 X 0.008670520231213872
# Epoch 1/10
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 2/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 3/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 4/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 5/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 6/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 7/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 8/10
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 9/10
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 10/10
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0023 - accuracy: 1.0000
# Validation Accuracy: 1.0

# %% [markdown]
# # Evaluation the model
# For evaluation, we use the average accuracy of the seven folds. beside that, using the recall that measures the sensitivity of the ROC (area under the ROC curve) and the ROC (receiver operating characteristic curve) itself.

# %%
# to print the average accuracy across all folds
print("Average Accuracy Neural Network: {}".format(np.mean(accuracy_scores)))

# to evaluate the model on the test set
X_test_scaled = scaler.transform(data_Xtest)
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)

# to generate the confusion matrix
conf_matrix = confusion_matrix(data_ytest, y_pred)

# to print the classification report
print("\nClassification Report:\n", classification_report(data_ytest, y_pred))
print("Recall: ", recall_score(data_ytest, y_pred))

# to plot non-normalized confusion matrix
class_names = [0, 1]
plt.figure()
plot_confusion_matrix(conf_matrix, classes=class_names, title='Confusion matrix')
plt.show()
# Out:
# Average Accuracy Neural Network: 1.0
# 47/47 [==============================] - 0s 3ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1352
#            1       0.97      0.97      0.97       148
#
#     accuracy                           0.99      1500
#    macro avg       0.99      0.99      0.99      1500
# weighted avg       0.99      0.99      0.99      1500
#
# Recall:  0.972972972972973

# %%
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)


# to Plot ROC curve
fpr, tpr, _ = roc_curve(data_ytest, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# to find the minimum length of histories
min_length = min(len(history['loss']) for history in history_list)
# Out:
# 47/47 [==============================] - 0s 2ms/step

# %%
# to truncate or pad histories to have the same length
truncated_histories = []
for history in history_list:
    truncated_history = {
        'loss': history['loss'][:min_length],
        'val_loss': history['val_loss'][:min_length],
        'accuracy': history['accuracy'][:min_length],
        'val_accuracy': history['val_accuracy'][:min_length]
    }
    truncated_histories.append(truncated_history)

# %%
# to calculate mean values for each epoch
mean_loss = np.mean([history['loss'] for history in truncated_histories], axis=0)
mean_val_loss = np.mean([history['val_loss'] for history in truncated_histories], axis=0)
mean_accuracy = np.mean([history['accuracy'] for history in truncated_histories], axis=0)
mean_val_accuracy = np.mean([history['val_accuracy'] for history in truncated_histories], axis=0)

# %%
# to plot mean training/validation loss and accuracy
plt.figure(figsize=(12, 4))

# to lot Mean Loss
plt.subplot(1, 2, 1)
plt.plot(mean_loss, label='Mean Training Loss')
plt.plot(mean_val_loss, label='Mean Validation Loss')
plt.title('Mean Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Mean Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_accuracy, label='Mean Training Accuracy')
plt.plot(mean_val_accuracy, label='Mean Validation Accuracy')
plt.title('Mean Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                992
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1537 (6.00 KB)
# Trainable params: 1537 (6.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
